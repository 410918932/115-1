# %% [markdown]
# <a href="https://colab.research.google.com/github/410918932/115-1/blob/main/410918932_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
money = 50000
rate  = 0.015
year  = 5
total = money * (1+rate)**year
print(total)
# Out:
# 53864.20019421873
