# %% [markdown]
# <a href="https://colab.research.google.com/github/410918932/115-1/blob/main/410918932_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
coin=int(input("請輸入目前金幣數量"))
earn_coin=int(input("請輸入獲得金幣數量:"))
print(f"任務完成!你現在有{coin+earn_coin}枚金幣")
# Out:
# 請輸入目前金幣數量500
# 請輸入獲得金幣數量:250
# 任務完成!你現在有750枚金幣
